# %% [markdown]
# ## Exploratory Data Analysis of Netflix Movies

# %% [markdown]
# *Summary*: This dataset contains 16 years of Netflix movie records, spanning from 2008 up to 2023. It includes detailed information about movies available onn Netflix such as title, director, release year, genre, duration, country of production, and ratings.
#
# *Objective*: The objective of this project is to perform an in-depth exploratory data analysis (EDA) of Netflix movies to discover significant patterns and insights. The analysis will emphasize genres, countries, languages, and directors to determine which categories are most popular and best rated. In addition, broader metrics such as ratings, popularity, budget, and revenue will be explored to identify performance trends. This approach will enable a comparative view of different aspects of movies and highlight the key factors contributing to audience engagement and commercial success.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import dataset
df = pd.read_csv("Users/praneethpannu/Downloads/Netflix Movies.csv")

# %%
df
# Out:
#        show_id   type                                         title  \
# 0        10192  Movie                           Shrek Forever After
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# ...        ...    ...                                           ...
# 15995  1440286  Movie         Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                                 Man and Woman
# 15997  1426364  Movie              Night of the Dead Sorority Babes
# 15998  1411248  Movie                               A Dunces Burden
# 15999  1405742  Movie                                Portal to Hell
#
#                                     director  \
# 0                              Mike Mitchell
# 1                          Christopher Nolan
# ...

# %%
df.head(3)
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
#
#             director                                               cast  \
# 0      Mike Mitchell  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2        David Yates  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
#
#                                     country  date_added  release_year  rating  \
# 0                  United States of America  2010-05-16          2010   6.380
# 1  United Kingdom, United States of America  2010-07-15          2010   8.369
# 2  United Kingdom, United States of America  2010-11-17          2010   7.744
#
#    duration                                         genres language  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
df.shape
# Out:
# (16000, 18)

# %%
df.describe()
# Out:
#             show_id  release_year        rating  duration    popularity  \
# count  1.600000e+04  16000.000000  16000.000000       0.0  16000.000000
# mean   5.266582e+05   2017.500000      5.956368       NaN     20.384728
# std    3.794427e+05      4.609916      1.754741       NaN     68.610033
# min    1.890000e+02   2010.000000      0.000000       NaN      3.860000
# 25%    2.257258e+05   2013.750000      5.600000       NaN      7.840750
# 50%    4.468170e+05   2017.500000      6.300000       NaN     10.913500
# 75%    7.739808e+05   2021.250000      6.923000       NaN     17.336500
# max    1.440471e+06   2025.000000     10.000000       NaN   3876.006000
#
#          vote_count  vote_average        budget       revenue
# count  16000.000000  16000.000000  1.600000e+04  1.600000e+04
# mean     718.656125      5.956368  8.766792e+06  2.446308e+07
# std     2080.198316      1.754741  2.912450e+07  1.116977e+08
# min        0.000000      0.000000  0.000000e+00  0.000000e+00
# ...

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director          132
# cast              204
# country           466
# date_added          0
# release_year        0
# rating              0
# duration        16000
# genres            107
# language            0
# description       132
# popularity          0
# vote_count          0
# vote_average        0
# budget              0
# revenue             0
# dtype: int64

# %%
# Handle missing values
df.fillna({'director': 'Unknown', 'cast': 'Unknown', 'country': 'Unknown', 'genres': 'Unknown'}, inplace=True)
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director            0
# cast                0
# country             0
# date_added          0
# release_year        0
# rating              0
# duration        16000
# genres              0
# language            0
# description       132
# popularity          0
# vote_count          0
# vote_average        0
# budget              0
# revenue             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             show_id  release_year        rating  duration    popularity  \
# count  1.600000e+04  16000.000000  16000.000000       0.0  16000.000000
# mean   5.266582e+05   2017.500000      5.956368       NaN     20.384728
# std    3.794427e+05      4.609916      1.754741       NaN     68.610033
# min    1.890000e+02   2010.000000      0.000000       NaN      3.860000
# 25%    2.257258e+05   2013.750000      5.600000       NaN      7.840750
# 50%    4.468170e+05   2017.500000      6.300000       NaN     10.913500
# 75%    7.739808e+05   2021.250000      6.923000       NaN     17.336500
# max    1.440471e+06   2025.000000     10.000000       NaN   3876.006000
#
#          vote_count  vote_average        budget       revenue
# count  16000.000000  16000.000000  1.600000e+04  1.600000e+04
# mean     718.656125      5.956368  8.766792e+06  2.446308e+07
# std     2080.198316      1.754741  2.912450e+07  1.116977e+08
# min        0.000000      0.000000  0.000000e+00  0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      16000 non-null  object
#  4   cast          16000 non-null  object
#  5   country       16000 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        16000 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
df.nunique()
# Out:
# show_id         16000
# type                1
# title           15485
# director         9509
# cast            15640
# country          1464
# date_added       4423
# release_year       16
# rating           2145
# duration            0
# genres           2769
# language           74
# description     15854
# popularity      11173
# vote_count       2693
# vote_average     2145
# budget            958
# revenue          5327
# dtype: int64

# %%
# Add a new column 'profit' by subtracting 'budget' from 'revenue'
df['profit'] = df['revenue'] - df['budget']
df
# Out:
#        show_id   type                                         title  \
# 0        10192  Movie                           Shrek Forever After
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# ...        ...    ...                                           ...
# 15995  1440286  Movie         Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                                 Man and Woman
# 15997  1426364  Movie              Night of the Dead Sorority Babes
# 15998  1411248  Movie                               A Dunces Burden
# 15999  1405742  Movie                                Portal to Hell
#
#                                     director  \
# 0                              Mike Mitchell
# 1                          Christopher Nolan
# ...

# %% [markdown]
# ### Identifying Top Movies Based on Key Metrics

# %%
# Top 10 Movies by Revenue
top10_revenue_movies = df.sort_values(by='revenue', ascending=False).head(10)
top10_revenue_movies[['title', 'revenue']]
# Out:
#                               title     revenue
# 9001              Avengers: Endgame  2799439100
# 12006      Avatar: The Way of Water  2320250281
# 5010   Star Wars: The Force Awakens  2068223624
# 8000         Avengers: Infinity War  2052415039
# 15019                      Ne Zha 2  1990000000
# 11000       Spider-Man: No Way Home  1921847111
# 14026                  Inside Out 2  1698863816
# 5001                 Jurassic World  1671537444
# 9000                  The Lion King  1662020819
# 2000                   The Avengers  1518815515

# %%
# Top 10 Movies by Budget
top10_budget_movies = df.sort_values(by='budget', ascending=False).head(10)
top10_budget_movies[['title', 'budget']]
# Out:
#                                              title     budget
# 12006                     Avatar: The Way of Water  460000000
# 9006              Star Wars: The Rise of Skywalker  416000000
# 15078                         Avatar: Fire and Ash  400000000
# 15044    Mission: Impossible - The Final Reckoning  400000000
# 13093            Ant-Man and the Wasp: Quantumania  388369742
# 1001   Pirates of the Caribbean: On Stranger Tides  379000000
# 5006                       Avengers: Age of Ultron  365000000
# 9001                             Avengers: Endgame  356000000
# 13003                                       Fast X  340000000
# 15066                           The Electric State  320000000

# %%
# Top 10 Movies by Popularity
top10_popular_movies = df.sort_values(by='popularity', ascending=False).head(10)
top10_popular_movies[['title', 'popularity']]
# Out:
#                                   title  popularity
# 15000                         The Gorge    3876.006
# 15001                       Flight Risk    3320.616
# 14000             Mufasa: The Lion King    2643.627
# 14001              Sonic the Hedgehog 3    2402.503
# 14002                           Moana 2    2347.007
# 14003                            Amaran    1780.289
# 15002  Captain America: Brave New World    1495.724
# 15003                         Companion    1283.362
# 14004                        Panda Plan    1214.508
# 14005                 Kraven the Hunter    1195.885

# %%
# Top 10 Profitable Movies
top10_profitable_movies = df.sort_values(by='profit', ascending=False).head(10)
top10_profitable_movies[['title', 'profit']]
# Out:
#                               title      profit
# 9001              Avengers: Endgame  2443439100
# 15019                      Ne Zha 2  1910000000
# 12006      Avatar: The Way of Water  1860250281
# 5010   Star Wars: The Force Awakens  1823223624
# 8000         Avengers: Infinity War  1752415039
# 11000       Spider-Man: No Way Home  1721847111
# 5001                 Jurassic World  1521537444
# 14026                  Inside Out 2  1498863816
# 9000                  The Lion King  1402020819
# 5008                      Furious 7  1325400000

# %% [markdown]
# ### Top 10 Movies with the Highest Revenue

# %%
# For Revenue
top10_revenue_movies.reset_index(drop=True)[['title', 'revenue']]
# Out:
#                           title     revenue
# 0             Avengers: Endgame  2799439100
# 1      Avatar: The Way of Water  2320250281
# 2  Star Wars: The Force Awakens  2068223624
# 3        Avengers: Infinity War  2052415039
# 4                      Ne Zha 2  1990000000
# 5       Spider-Man: No Way Home  1921847111
# 6                  Inside Out 2  1698863816
# 7                Jurassic World  1671537444
# 8                 The Lion King  1662020819
# 9                  The Avengers  1518815515

# %% [markdown]
# ### Top 10 Most Popular Movies

# %%
# For Popular Movies
top10_popular_movies.reset_index(drop=True)[['title', 'popularity']]
# Out:
#                               title  popularity
# 0                         The Gorge    3876.006
# 1                       Flight Risk    3320.616
# 2             Mufasa: The Lion King    2643.627
# 3              Sonic the Hedgehog 3    2402.503
# 4                           Moana 2    2347.007
# 5                            Amaran    1780.289
# 6  Captain America: Brave New World    1495.724
# 7                         Companion    1283.362
# 8                        Panda Plan    1214.508
# 9                 Kraven the Hunter    1195.885

# %% [markdown]
# ### Top 10 Profitable Movies

# %%
# For Profitable Movies
top10_profitable_movies.reset_index(drop=True)[['title', 'profit']]
# Out:
#                           title      profit
# 0             Avengers: Endgame  2443439100
# 1                      Ne Zha 2  1910000000
# 2      Avatar: The Way of Water  1860250281
# 3  Star Wars: The Force Awakens  1823223624
# 4        Avengers: Infinity War  1752415039
# 5       Spider-Man: No Way Home  1721847111
# 6                Jurassic World  1521537444
# 7                  Inside Out 2  1498863816
# 8                 The Lion King  1402020819
# 9                     Furious 7  1325400000

# %% [markdown]
# ## Global Metrics Distribution

# %% [markdown]
# #### Set the Visual Theme for All Charts

# %%
# Global customization for all plots
sns.set_theme(style="whitegrid")
plt.rcParams.update({
    "figure.figsize": (8, 5),
    "figure.facecolor": "white",
    "axes.facecolor": "white",
    "axes.edgecolor": "black",
    "axes.labelcolor": "black",
    "axes.titlecolor": "darkblue",
    "axes.titlesize": 14,
    "axes.labelsize": 12,
    "xtick.color": "black",
    "ytick.color": "black",
    "grid.color": "#dddddd",
    "grid.linestyle": "--",
    "grid.alpha": 0.8,
    "legend.facecolor": "white",
    "legend.edgecolor": "black",
    "legend.fontsize": 10,
})

# %% [markdown]
# #### Distribution of Movie Popularity Scores on Netflix

# %%
# Distribution of Movie Popularity

sns.set_palette("pastel")
sns.histplot(x='popularity', data=df[df['popularity'] < 100], kde=True, bins=50)
plt.ylabel('Number of Movies')
plt.title('Distribution of Movie Popularity on Netflix')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distribution of Movie Ratings on Netflix

# %%
# Distribution of Movie Ratings

sns.histplot(x='rating', data=df[df['rating'] >0], kde=True, bins=50)
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movie Rating on Netflix')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Budget vs Revenue Distributions on Netflix Movies (Log Scale)

# %%
# Make sure budget and revenue for log scale

df_plot = df[(df['budget'] > 0) & (df['revenue'] > 0)]

# Figure size
plt.figure(figsize=(12, 6))

# Budget distribution
plt.subplot(1, 2, 1)
sns.histplot(df_plot['budget'], bins=50, log_scale=True, kde=True)
plt.title('Budget Distribution (Log Scale)')
plt.xlabel('Budget')
plt.ylabel('Count')

# Revenue distribution
plt.subplot(1, 2, 2)
sns.histplot(df_plot['revenue'], bins=50, log_scale=True, kde=True)
plt.title('Revenue Distribution (Log Scale)')
plt.xlabel('Revenue')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Relationship Between Budget, Revenue, Popularity and Ratings

# %%
# Select the relevant columns
corr_cols = ['budget', 'revenue', 'popularity', 'vote_count', 'vote_average']
corr = df[corr_cols].corr()

# Plot the heatmap
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correltion Heatmap')
plt.show()

# %% [markdown]
# ### Genre Analysis

# %%
# Spilting & Exploding
df['genres'] = df['genres'].str.split(', ')
df_exploded = df.explode('genres')
df_exploded['genres'] = df_exploded['genres'].astype(str).str.strip()

# %%
df_exploded['genres'].head()
# Out:
# 0       Comedy
# 0    Adventure
# 0      Fantasy
# 0    Animation
# 0       Family
# Name: genres, dtype: object

# %%
# Group by 'genres'

genres_group = (df_exploded.groupby('genres').agg(
    number_of_movies = ('show_id', 'count'),
    avg_rating = ('rating', 'mean'),
    avg_popularity = ('popularity', 'mean'),
    avg_vote_count = ('vote_count', 'mean'),
    avg_revenue = ('revenue', 'mean'),
    avg_budget = ('budget', 'mean'),
    avg_profit = ('profit', 'mean')).sort_values(by = 'number_of_movies', ascending=False).reset_index())

# %%
genres_group.head(10)
# Out:
#       genres  number_of_movies  avg_rating  avg_popularity  avg_vote_count  \
# 0      Drama              6910    6.160090       16.719860      628.725615
# 1     Comedy              4533    6.073928       19.418328      716.551291
# 2   Thriller              3769    5.843899       24.490540      803.976652
# 3     Action              3239    6.073126       32.214458     1287.368632
# 4    Romance              2571    5.957180       19.166187      524.499806
# 5     Horror              2425    5.436848       21.447152      594.854021
# 6  Adventure              1768    6.295425       35.469354     1965.972285
# 7      Crime              1738    6.182608       21.600593      844.681243
# 8  Animation              1579    6.741792       28.611641      727.349588
# 9     Family              1472    6.473992       28.364884      893.233696
#
#     avg_revenue    avg_budget    avg_profit
# 0  1.442036e+07  6.039072e+06  8.381291e+06
# 1  2.762601e+07  9.227067e+06  1.839894e+07
# ...

# %% [markdown]
# #### Top 10 Genre Base on Number of Movies

# %%
# Plot top 10 genres based on number of movies
sns.barplot(x = 'number_of_movies', y = 'genres', data = genres_group.head(10))
plt.xlabel('Number of Movies')
plt.ylabel('Genres')
plt.title('Top 10 Genres Based on Number of Movies')
plt.show()

# %% [markdown]
# #### Top 10 Genres by Average Rating

# %%
# Plot top 10 genres based on average rating
sns.barplot(x='avg_rating', y='genres', data=genres_group.sort_values(by='avg_rating', ascending=False).head(10))
plt.xlabel("Avgerage Rating")
plt.ylabel("Genre")
plt.title("Top 10 Genres by Average Rating")
plt.show()

# %% [markdown]
# #### Top 10 Genres by Average Popularity

# %%
# Plot top 10 genres based on average popularity
sns.barplot(x='avg_popularity', y='genres', data=genres_group.sort_values(by='avg_popularity', ascending=False).head(10))
plt.xlabel("Average Popularity")
plt.ylabel("Genre")
plt.title("Top 10 Genres by Average Popularity")
plt.show()

# %% [markdown]
# ### Country Analysis

# %% [markdown]
# In this section, we will analyze Netflix movies based on their production countries. The
# goal is to:
#
# - Identify the top countries producing the most content.
# - Compare countries by average ratings, budget and revenue.
# - Analyze average rating and average popularity of countries.
# - Study the trend of movie production over the years for leading countries.

# %%
# country wise explode with primary country and equal profit distribution

# Split and explode country column into list
df['country'] = df['country'].str.split(', ')
df_exploded = df.explode('country')
# create primary country
df['primary_country'] = df['country'].apply(lambda x: x[0].strip() if isinstance(x, list) else x)

# Remove extra spaces
df_exploded['country'] = df_exploded['country'].astype(str).str.strip()

# Divide profit equally among countries
df_exploded['profit_divided'] = df_exploded['profit'] / df_exploded.groupby('show_id')['country'].transform('count')

# %%
# Check the DataFrame after exploding and add primary column
df_exploded.iloc[:,[5,17]].head(5)
# Out:
#                     country    revenue
# 0  United States of America  752600867
# 1            United Kingdom  839030630
# 1  United States of America  839030630
# 2            United Kingdom  954305868
# 2  United States of America  954305868

# %%
# Group by 'country' to get count and average metrics for easier country-wise analysis

countries_group = (df_exploded[df_exploded['country'] != 'Unknown'].groupby('country').agg(
    number_of_movies = ('show_id', 'count'),
    avg_rating = ('rating', 'mean'),
    avg_popularity = ('popularity', 'mean'),
    avg_vote_count = ('vote_count', 'mean'),
    avg_revenue = ('revenue', 'mean'),
    avg_budget = ('budget', 'mean'),
    avg_profit = ('profit_divided', 'mean')
    ).reset_index().sort_values(by = 'number_of_movies', ascending=False))

# Filter countries with at least 500 movies
filtered_countries = countries_group[countries_group['number_of_movies'] >= 500]

# %% [markdown]
# ### Top Producing Countries

# %%
sns.barplot(x='number_of_movies', y='country', data=filtered_countries.head(10))
plt.xlabel('Number of Movies')
plt.ylabel('Country')
plt.title('Top Producing Countries on Netflix')
plt.show()

# %% [markdown]
# #### Compare Budget, Revenue and Profit by Countries

# %%
from matplotlib.ticker import FuncFormatter
def millions(x, pos):
    return f'{x/1_000_000:.1f}M'

# Budget Plot
fig, ax = plt.subplots(figsize=(16, 8))
sns.barplot(
    x='avg_budget', 
    y='country', 
    data=filtered_countries.sort_values(by='avg_budget', ascending=False).head(10)
)
ax.set_title('Top 10 Countries by Average Budget')
ax.set_xlabel('Budget (log scale)')
ax.set_ylabel('Country')
ax.xaxis.set_major_formatter(FuncFormatter(millions))
plt.tight_layout()
plt.show()

# %%
# Revenue Plot
fig, ax = plt.subplots(figsize=(16, 8))
sns.barplot(
    x='avg_revenue',
    y='country',
    data=filtered_countries.sort_values(by='avg_revenue', ascending=False).head(10),
    ax=ax
)
ax.set_title('Top 10 Countries by Average Revenue')
ax.set_xlabel('Revenue (log scale)')
ax.set_ylabel('Country')
ax.xaxis.set_major_formatter(FuncFormatter(millions))
plt.tight_layout()
plt.show()

# %%
# Profit Plot
fig, ax = plt.subplots(figsize=(16, 8))
sns.barplot(
    x='avg_profit',
    y='country',
    data=filtered_countries.sort_values(by='avg_profit', ascending=False).head(10),
    ax=ax
)
ax.set_title('Top 10 Countries by Average Profit')
ax.set_xlabel('Profit (log scale)')
ax.set_ylabel('Country')
ax.xaxis.set_major_formatter(FuncFormatter(millions))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top Average Rating Countries

# %%
# Average Rating Countries
sns.barplot(
	x='avg_rating',
	y='country',
	data=filtered_countries.sort_values(by='avg_rating', ascending=False).head(10)
)
plt.xlabel("Average Rating")
plt.ylabel("Country")
plt.title("Top 10 Countries by Average Rating")
plt.show()

# %% [markdown]
# ### Top Average Popularity Countries

# %%
# Average Popularity Countries
sns.barplot(
    x='avg_popularity',
    y='country',
    data=filtered_countries.sort_values(by='avg_popularity', ascending=False).head(10)
)
plt.xlabel("Average Popularity")
plt.ylabel("Country")
plt.title("Average Popularity by countries")
plt.show()

# %% [markdown]
# #### Movie Release Trend of Top 5 Countries

# %%
# Top 5 countries
top5_countries = df_exploded.groupby('country')['show_id'].count().sort_values(ascending=False).head(5).index.tolist()

# filter
df_top5 = df_exploded[df_exploded['country'].isin(top5_countries)]

# Group by
trend_df = df_top5.groupby(['country', 'release_year'], as_index=False)['show_id'].count()

# plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='release_year', y='show_id', hue='country', data=trend_df, marker='o')
plt.title('Movie Release per Year of Top 5 Countries')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.legend(title='Countries')
plt.show()

# %% [markdown]
# ### Language Analysis

# %% [markdown]
# In this section, we analyze Netflix movies based on languages. The goal is to identify:
# - Most common languages used in Netflix movies.
# - Languages associated with the highest average ratings.
# - Languages generating the most profit.

# %% [markdown]
# #### Language-wise Movie Distribution

# %%
# Top 5 languages by number of movies
top_languages = df['language'].value_counts().head(5)

# Calculate 'Others' as sum of remaining languages
others_count = df['language'].value_counts().iloc[5:].sum()
top_languages['Others'] = others_count

# Pie chart
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    top_languages,
    labels=top_languages.index,
    autopct='%1.1f%%',
    startangle=140,
)

# Set Language Labels to Black
for text in texts:
    text.set_color('Black')

# Set Percentage text to White
for autotext in autotexts:
    autotext.set_color('White')

plt.title("Movie Distribution by Language", fontsize=14, fontweight='bold', color='blue')
plt.show()

# %%
# Group by 'language' to get count and average metrics for easier language wise analysis
language_group = (
    df_exploded.groupby('language')
    .agg(
        number_of_movies = ('show_id', 'count'),
        avg_rating = ('rating', 'mean'),
        avg_popularity = ('popularity', 'mean'),
        avg_vote_count = ('vote_count', 'mean'),
        avg_revenue = ('revenue', 'mean'),
        avg_budget = ('budget', 'mean'),
        avg_profit = ('profit', 'mean')
    ).reset_index().sort_values(by='number_of_movies', ascending=False)
)

# %% [markdown]
# #### Top Average Rating Languages

# %%
# Plot Average Rating Languages
sns.barplot(
    x='avg_rating',
    y='language',
    data=language_group.sort_values(by='avg_rating', ascending=False).head(10)
)
plt.xlabel("Avgerage Rating")
plt.ylabel("Language")
plt.title("average Rating by Language")
plt.show()

# %% [markdown]
# #### Top Average Porfit Languages

# %%
# plot of Average Profit Languages
sns.barplot(
    x='avg_profit',
    y='language',
    data=language_group.sort_values(by='avg_profit', ascending=False).head(10)
)
plt.xlabel("Average Profit")
plt.ylabel("Language")
plt.title("Average Profit by Language")
ax = plt.gca()
ax.xaxis.set_major_formatter(FuncFormatter(millions))
plt.show()

# %% [markdown]
# ### Director Analysis

# %% [markdown]
# In this section, we analyze Netflix movies based on directors. The goal is to identify:
# - Top directors with the highest number of movies.
# - Most profitable directors.
# - Directors with the best average ratings.

# %% [markdown]
# #### Top directors with the highest number of movies.

# %%
# Director wise grouping
director_group = (
    df_exploded[df_exploded['director'] != 'Unknown'].groupby('director')
    .agg(
        number_of_movies = ('show_id', 'count'),
        avg_rating = ('rating', 'mean'),
        avg_popularity = ('popularity', 'mean'),
        avg_vote_count = ('vote_count', 'mean'),
        avg_revenue = ('revenue', 'mean'),
        avg_budget = ('budget', 'mean'),
        avg_profit = ('profit', 'mean'),
    ).reset_index().sort_values(by='number_of_movies', ascending=False)
)

# Plot the top 10 directors with the highest number of movies using a horizontal bar chart
sns.barplot(
    x='number_of_movies',
    y='director',
    data=director_group.head(10)
)
plt.title('Number of Movies Directed by Each Director')
plt.xlabel('Number of Movies')
plt.ylabel('Director')
plt.show()

# %% [markdown]
# #### Directors with the best average ratings.

# %%
# Directors with more than 5 movies to ensure reliable averages
filtered = director_group[director_group['number_of_movies'] > 5]

# Plot Average Rating by Director
sns.barplot(
    x='avg_rating',
    y='director',
    data=filtered.sort_values(by='avg_rating', ascending=False).head(10))
plt.title("Top 10 Directors with Highest Average Ratings")
plt.xlabel("Average Rating", fontsize=12)
plt.ylabel("Director", fontsize=12)
plt.show()

# %% [markdown]
# #### Top Profitable Directors

# %%
# Select the Top 10 directors with the highest average profit
top_profitable = filtered.sort_values(by='avg_profit', ascending=False).head(10)

# Bar plot of the top 10 directors
sns.barplot(
    x='avg_profit',
    y='director',
    data=top_profitable
)
plt.title("Top 10 Most Profitable Directors")
plt.xlabel("Average Profit", fontsize=12)
plt.ylabel("Director", fontsize=12)
ax = plt.gca()
ax.xaxis.set_major_formatter(FuncFormatter(millions))
plt.show()

# %% [markdown]
# ### Overall Conclusion

# %% [markdown]
# - Netflix's catalog is dominated by U.S. productions and English-language content,
# with a rich variety of genres appealing to diverse audiences.
# - Most movies have moderate popularity and average ratings, while a few high-
# budget blockbusters generate exceptional revenue and profit.
# - Financial success is often linked to high production budgets and international
# appeal, though some exceptions exist.
# - Content has been consistently added over the years, reflecting a steady growth
# strategy.
# - Netflix balances specialized independent films with major releases, ensuring both
# broad reach and engagement with focused audiences.
